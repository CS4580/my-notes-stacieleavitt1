# %% [markdown]
# ## Task: Game Platform Preference
#
# You are interested in creating your own video game. Analyze a dataset from IGN which ranks the different platforms and game types.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print('Setup Complete')
# Out:
# Setup Complete

# %% [markdown]
# ### Load and Review Data
# For this analysis we will use the : `data/ign_scores.csv`
# - Use the `Platform` column as index

# %%
file_path = '../data/ign_scores.csv'
data_df = pd.read_csv(file_path, index_col='Platform')
print(data_df.head())
# Out:
#                     Action  Action, Adventure  Adventure  Fighting  \
# Platform
# Dreamcast         6.882857           7.511111   6.281818  8.200000
# Game Boy Advance  6.373077           7.507692   6.057143  6.226316
# Game Boy Color    6.272727           8.166667   5.307692  4.500000
# GameCube          6.532584           7.608333   6.753846  7.422222
# Nintendo 3DS      6.670833           7.481818   7.414286  6.614286
#
#                   Platformer    Puzzle       RPG    Racing   Shooter  \
# Platform
# Dreamcast           8.340000  8.088889  7.700000  7.042500  7.616667
# Game Boy Advance    6.970588  6.532143  7.542857  6.657143  6.444444
# Game Boy Color      6.352941  6.583333  7.285714  5.897436  4.500000
# GameCube            6.665714  6.133333  7.890909  6.852632  6.981818
# Nintendo 3DS        7.503448  8.000000  7.719231  6.900000  7.033333
#
#                   Simulation    Sports  Strategy
# Platform
# Dreamcast           7.628571  7.272222  6.433333
# Game Boy Advance    6.928571  6.694444  7.175000
# Game Boy Color      5.900000  5.790698  7.400000
# GameCube            8.028571  7.481319  7.116667
# Nintendo 3DS        7.700000  6.388889  7.900000

# %% [markdown]
# ### Task: Which Platform is Best?
#
# Create a bar chart that shows the average score for `racing` games, for each platform

# %%
plt.figure(figsize=(16,6))
sns.barplot(x=data_df['Racing'], y=data_df.index)
plt.xlabel('Average Score')
# Out:
# Text(0.5, 0, 'Average Score')

# %% [markdown]
# ### Task: Which one is Best One for Racing Games?
# If `Wii` platform is not the best, which platform is?

# %%
platform_high_score = data_df['Racing'].idxmax()
print(f'Platform with the highest avg score for racing games is {platform_high_score}')
# Out:
# Platform with the highest avg score for racing games is Xbox One

# %% [markdown]
# ### Task: All Possible Combinations
# Create a Heatmap of the average scores by genre in each cell

# %%
plt.figure(figsize=(16,6))
plt.title('Average Scores by genre in each cell')
sns.heatmap(data=data_df, annot=True)
plt.xlabel('Genre')
# Out:
# Text(0.5, 36.72222222222221, 'Genre')

# %% [markdown]
# ### Task: Which Combination is Best?
# - Which combination of `genre` and `platform` receives the `highest` average ratings?
# - Which combination receives the `lowest` average rating?

# %%
# stack() method makes a Series with multi-level index
# only issue is that if you have a tie by chance, it'll just pick the first one
highest_combination = data_df.stack().idxmax() # get tuple with columns
highest_combination_value = data_df.stack().max() #get value
lowest_combination = data_df.stack().idxmin()
lowest_combination_value = data_df.stack().min()

print(f'Highest Combination is: {highest_combination} with a rating of {highest_combination_value}')
print(f'Lowest Combination is: {lowest_combination} with a rating of {lowest_combination_value}')
# Out:
# Highest Combination is: ('PlayStation 4', 'Simulation') with a rating of 9.25
# Lowest Combination is: ('Game Boy Color', 'Fighting') with a rating of 4.5

# %% [markdown]
# ## Task: Candy Preference
# Analyze a candy survey dataset called: `data/candy.csv` for favorite candies.
#
# ### Setup and Load Data

# %%
# Load data
file_path = '../data/candy.csv'
candy_df = pd.read_csv(file_path, index_col = 'id')
# Top records
candy_df.head()
# Out:
#    competitorname chocolate fruity caramel peanutyalmondy nougat  \
# id
# 0       100 Grand       Yes     No     Yes             No     No
# 1    3 Musketeers       Yes     No      No             No    Yes
# 2       Air Heads        No    Yes      No             No     No
# 3      Almond Joy       Yes     No      No            Yes     No
# 4       Baby Ruth       Yes     No     Yes            Yes    Yes
#
#    crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# id
# 0               Yes   No  Yes       No         0.732         0.860   66.971725
# 1                No   No  Yes       No         0.604         0.511   67.602936
# 2                No   No   No       No         0.906         0.511   52.341465
# 3                No   No  Yes       No         0.465         0.767   50.347546
# 4                No   No  Yes       No         0.604         0.767   56.914547

# %%
# Get the size
print(candy_df.shape)
# Out:
# (83, 13)

# %% [markdown]
# ### Task: Popularity
# Which candy, '3 Musketeers' or 'Almond Joy' was more popular?

# %%
sns.barplot(x=candy_df['competitorname'], y=candy_df['winpercent'])
# Out:
# <Axes: xlabel='competitorname', ylabel='winpercent'>

# %% [markdown]
# Create a scatter plot that shows the correlation between `sugarpercent` (x-axis) and `winpercent` (y-axis)
# - Does the plot show a **strong** correlation between the two variables?
# - If so, are candies with more sugar relatively more or less popular with survey data?

# %%
# Scatter plot of sugarpercent vs winpercent
sns.scatterplot(data=candy_df, x='sugarpercent', y='winpercent')
# Out:
# <Axes: xlabel='sugarpercent', ylabel='winpercent'>
